# %% [markdown]
# # About
# Since the current data size is too big, we will reduce the dataset to just a handful of patients, which will make the Dash app work faster and better.
# We will select patients based on some criteria that allows a good representative sample of the 'comparative cohort' while highlighting some aspects of the Dash app.

# %% [markdown]
# # Set Up

# %%
import os
os.chdir('../src')

# %%
import pandas as pd
import pickle

# %%
df = pickle.load(open('../data/intermediate/patient_demographics.pkl','rb'))
visits_data = pickle.load(open('../data/intermediate/visits_data.pkl','rb'))
visit_types_list = list(visits_data.groupby('VisitType')['VisitID'].count().sort_values(ascending=False).index.dropna())
disease_list = visits_data.DiseaseCat.unique().tolist()

# %%
visits_data
# Out:
#          PatientID   VisitID  Days   VisitType  CGI     Medication  Dose  \
# 0               92      1667   105  Outpatient    2     fluoxetine  20.0
# 1               92      1668   105  Outpatient    1     fluoxetine  20.0
# 2               92      1669   104  Outpatient    1     fluoxetine  20.0
# 3               92      1673   104  Outpatient    1     fluoxetine  20.0
# 4               92      1674   103  Outpatient    1     fluoxetine  20.0
# ...            ...       ...   ...         ...  ...            ...   ...
# 1355671     458700  14038464    14  Outpatient    6    risperidone   0.5
# 1355672     458700  14038465    13  Outpatient    6  amitriptyline  25.0
# 1355673     458700  14038465    13  Outpatient    6     citalopram  20.0
# 1355674     458700  14038465    13  Outpatient    6     clonazepam   0.5
# 1355675     458700  14038465    13  Outpatient    6    risperidone   0.5
#
#         Regimen                                          Diagnosis   DSMNo  \
# 0           1.0                      Diagnosis Deferred on Axis II   799.9
# 1           1.0                                    Bulimia Nervosa  307.51
# 2           1.0                                  Opioid Dependence  304.00
# 3           1.0                                  Opioid Dependence  304.00
# 4           1.0                      Diagnosis Deferred on Axis II   799.9
# ...         ...                                                ...     ...
# 1355671     2.0                            No Diagnosis on Axis II  V71.09
# 1355672     1.0  Major Depressive Disorder, Recurrent, Severe w...  296.34
# 1355673     1.0  Major Depressive Disorder, Recurrent, Severe w...  296.34
# 1355674     1.0                     Post-Traumatic Stress Disorder  309.81
# 1355675     2.0                     Post-Traumatic Stress Disorder  309.81
#
#                                         DiseaseCat
# 0                                           others
# 1                     feeding and eating disorders
# 2        substance-related and addictive disorders
# 3        substance-related and addictive disorders
# 4                                           others
# ...                                            ...
# 1355671                                     others
# 1355672                  major depressive disorder
# 1355673                  major depressive disorder
# 1355674      trauma and stressor related disorders
# 1355675      trauma and stressor related disorders
#
# [1355676 rows x 11 columns]

# %% [markdown]
# # Data Overview
#
# Original data size:

# %%
df.shape, visits_data.shape
# Out:
# ((14633, 4), (1355676, 11))

# %%
len(visits_data.PatientID.unique())
# Out:
# 14473

# %%
visits_data.groupby('DiseaseCat')['VisitID'].count().sort_values(ascending=False)
# Out:
# DiseaseCat
# major depressive disorder                            376963
# others                                               245439
# anxiety disorders                                    182627
# substance-related and addictive disorders            126786
# other mood disorder                                   85129
# trauma and stressor related disorders                 78848
# personality disorders                                 78525
# neurodevelopmental disorders                          52592
# schizophrenia and other psychotic disorders           33587
# bipolar disorders                                     33449
# adhd                                                  28140
# feeding and eating disorders                           7615
# neurocognitive disorders                               7514
# impulse-control disorders                              7001
# conduct disorder                                       3615
# sleep-wake disorders                                   2946
# mental disorders due to general medical condition      2007
# dissociative disorders                                 1822
# somatic symptom and related disorders                  1034
# factitious disorders                                     37
# Name: VisitID, dtype: int64

# %% [markdown]
# # Picking Patients
# Ideal patients:
# - have enough records in the database
# - have large changes in CGI
# - have tried a reasonable number of medications
# - have some comorbidities

# %%
ptgrp = visits_data.groupby('PatientID')
pts = ptgrp.agg({'VisitID':'count',
           'CGI' : ['std','min','max'],
           'Medication': 'nunique',
           'DiseaseCat':'nunique',
           'Days' : ['min','max']
          })

pts['duration'] = pts['Days']['max'] - pts['Days']['min'] + 1

# %%
# Filter criteria
pts_subset = pts[(pts['VisitID']['count']>10)&
                (pts['VisitID']['count']<=200)&
                (pts['DiseaseCat']['nunique']>2)&
                (pts['duration']>30)&(pts['duration']<=720)&
                (pts['CGI']['std']>0.5)]

# %%
pts_sample = list(pts_subset.index)

# %%
df_sample = df[df.PatientID.isin(pts_sample)]
visits_data_sample = visits_data[visits_data.PatientID.isin(pts_sample)]
# Out:
#        PatientID Sex   Race  Age
# 3            924   F  other   28
# 6           1651   F  other   51
# 7           1713   F  other   22
# 9           2107   F  white   35
# 12          2191   F  white   58
# ...          ...  ..    ...  ...
# 14618     457958   F  white   49
# 14623     457994   F  asian   55
# 14624     458003   F  asian   54
# 14630     458347   F  white   16
# 14632     458700   F  other   61
#
# [2519 rows x 4 columns]

# %% [markdown]
# # Saving Sampled Data
# Reduced the data sample to:

# %%
df_sample.shape, visits_data_sample.shape
# Out:
# ((2519, 4), (125163, 11))

# %%
with open('../data/intermediate/demographics_sample.pkl', 'wb') as f:
    pickle.dump(df_sample, f)
with open('../data/intermediate/visits_data_sample.pkl', 'wb') as f:
    pickle.dump(visits_data_sample, f)
